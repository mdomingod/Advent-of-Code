# %% [markdown]
# # D1 Star 1

# %%
left = [3, 4, 2, 1, 3, 3]
right = [4, 3, 5, 3, 9, 3]

left_s = sorted(left)
right_s = sorted(right)

left_s, right_s
# Out:
# ([1, 2, 3, 3, 3, 4], [3, 3, 3, 4, 5, 9])

# %%
out = [abs(left_s[i] - right_s[i]) for i in range(len(left_s))]
out
# Out:
# [2, 1, 0, 1, 2, 5]

# %%
sum(out)
# Out:
# 11

# %%
left_1 = []
right_1 = []
with open('input.txt', 'r') as file:
    for line in file:
        left_1.append(int(line[0:5]))
        right_1.append(int(line[8:]))

# %%
left_1[0:10], right_1[0:10]
# Out:
# ([80414, 17250, 23063, 89663, 27237, 81505, 67427, 95906, 19112, 92811],
#  [72092, 26414, 14603, 35210, 81657, 58579, 21819, 51098, 81697, 11615])

# %%
left_1s = sorted(left_1)
right_1s = sorted(right_1)

# %%
left_1s[0:10], right_1s[0:10]
len(left_1s) == len(right_1s)
# Out:
# True

# %%
out = [abs(left_1s[i] - right_1s[i]) for i in range(len(left_1s))]
out
sum(out)
# Out:
# 1646452

# %% [markdown]
# # D1 Star 2

# %%
left, right
# Out:
# ([3, 4, 2, 1, 3, 3], [4, 3, 5, 3, 9, 3])

# %%
list_2 = [right.count(i) * i for i in left]
list_2, sum(list_2)
# Out:
# ([9, 4, 0, 0, 9, 9], 31)

# %%
left_1[0:10], right_1[0:10]
# Out:
# ([80414, 17250, 23063, 89663, 27237, 81505, 67427, 95906, 19112, 92811],
#  [72092, 26414, 14603, 35210, 81657, 58579, 21819, 51098, 81697, 11615])

# %%
out_2 = [right_1.count(i) * i for i in left_1]
sum(out_2)
# Out:
# 23609874

# %% [markdown]
# # D2 Star 3

# %%
report = []
with open('exemple3.txt', 'r') as file:
    for line in file:
        report.append(line.split())

# %%
report[0]
# Out:
# ['7', '6', '4', '2', '1']

# %%
me = []
y = 0
safe = False
dict_3 = {}

for i in range(len(report[0])):
    curr = int(report[0][i])
    next = int(report[0][i+1])
    #print(curr, next)
    if curr > next:
        if curr - next <= 2:
            print(curr, next)
            safe = True
        else:
            safe = False
    else:
        pass
    
    if safe == True:
        dict_3["safe"] =+ 1
    print(safe)

print(dict_3)
# Out:
# 7 6
# True
# 6 4
# True
# 4 2
# True
# 2 1
# True
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 8
#       6 for i in range(len(report[0])+1):
#       7     curr = int(report[0][i])
# ----> 8     next = int(report[0][i+1])
#       9     #print(curr, next)
#      10     if curr > next:
#
# IndexError: list index out of range

# %%
for i in range(len(report)):
    for j in range(len(report[i])):
        print(report[i][j])
# Out:
# 7
# 6
# 4
# 2
# 1
# 1
# 2
# 7
# 8
# 9
# 9
# 7
# 6
# 2
# 1
# 1
# 3
# 2
# 4
# 5
# 8
# 6
# 4
# 4
# 1
# 1
# 3
# 6
# 7
# 9
