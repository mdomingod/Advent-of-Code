# %%
report_m = []


with open ("exemple_3.txt", "r") as file:
    for line in file:
        report_m.append(line.split())



for j in range(len(report_m)):
    report = report_m[j]
    diff = []
    s = 0
    #print(report)
    for i in range(len(report)-1):
        curr = int(report[i])
        next = int(report[i+1])
        diff_int = curr - next
        diff.append(diff_int)
        print(report, diff)

    
    if diff[0] > 0:
        print(report, diff[i], diff, "decrease")
        decrease = True

        if decrease == True:
            if diff[i] <= 3:
                s =+ 1
                print(s, "safe")
            
            else:
                s = 0
                print(s, "unsafe")
    
    else:
        print(report, diff[i], diff, "increase")
        increase = True

        if increase == True:
            if diff[i] >= -3:
                s =+ 1
                print(s, "safe")
            
            else:
                s = 0
                print(s, "unsafe")

    print(s)

    if s >= 4:
        print(s, "safe")

    else:
        print(s, "unsafe")      

    print(" ") # Separació de cada report
# Out:
# ['7', '6', '4', '2', '1'] [1]
# ['7', '6', '4', '2', '1'] [1, 2]
# ['7', '6', '4', '2', '1'] [1, 2, 2]
# ['7', '6', '4', '2', '1'] [1, 2, 2, 1]
# ['7', '6', '4', '2', '1'] 1 [1, 2, 2, 1] decrease
# 1 safe
# 1
# 1 unsafe
#
# ['1', '2', '7', '8', '9'] [-1]
# ['1', '2', '7', '8', '9'] [-1, -5]
# ['1', '2', '7', '8', '9'] [-1, -5, -1]
# ['1', '2', '7', '8', '9'] [-1, -5, -1, -1]
# ['1', '2', '7', '8', '9'] -1 [-1, -5, -1, -1] increase
# 1 safe
# 1
# 1 unsafe
#
# ['9', '7', '6', '2', '1'] [2]
# ['9', '7', '6', '2', '1'] [2, 1]
# ['9', '7', '6', '2', '1'] [2, 1, 4]
# ['9', '7', '6', '2', '1'] [2, 1, 4, 1]
# ['9', '7', '6', '2', '1'] 1 [2, 1, 4, 1] decrease
# 1 safe
# 1
# 1 unsafe
#
# ['1', '3', '2', '4', '5'] [-2]
# ['1', '3', '2', '4', '5'] [-2, 1]
# ['1', '3', '2', '4', '5'] [-2, 1, -2]
# ['1', '3', '2', '4', '5'] [-2, 1, -2, -1]
# ['1', '3', '2', '4', '5'] -1 [-2, 1, -2, -1] increase
# 1 safe
# 1
# 1 unsafe
#
# ['8', '6', '4', '4', '1'] [2]
# ['8', '6', '4', '4', '1'] [2, 2]
# ['8', '6', '4', '4', '1'] [2, 2, 0]
# ['8', '6', '4', '4', '1'] [2, 2, 0, 3]
# ['8', '6', '4', '4', '1'] 3 [2, 2, 0, 3] decrease
# 1 safe
# 1
# 1 unsafe
#
# ['1', '3', '6', '7', '9'] [-2]
# ['1', '3', '6', '7', '9'] [-2, -3]
# ['1', '3', '6', '7', '9'] [-2, -3, -1]
# ['1', '3', '6', '7', '9'] [-2, -3, -1, -2]
# ['1', '3', '6', '7', '9'] -2 [-2, -3, -1, -2] increase
# 1 safe
# 1
# 1 unsafe

# %% [markdown]
# print(dict[j][1])
#
#
#     for l in range(len(diff)):
#         print(dict[j][1][l])
#
#     print(" ")

# %%
report_m = []
dict = {}

with open ("exemple_3.txt", "r") as file:
    for line in file:
        report_m.append(line.split())



for j in range(len(report_m)):
    report = report_m[j]
    diff = []
    
    
    #print(report)
    for i in range(len(report)-1):
        curr = int(report[i])
        next = int(report[i+1])
        diff_int = curr - next
        diff.append(diff_int)
        dict[j] = [report, diff]

# %% [markdown]
# ### AIDA solution

# %%
def is_safe(report):
    increasing = True
    decreasing = True

    with open ("exemple_3.txt", "r") as file:
    for line in file:
        report_m.append(line.split())



    for j in range(len(report_m)):
        report = report_m[j]
        diff = []
    
    
        #print(report)
        for i in range(len(report)-1):
            curr = int(report[i])
            next = int(report[i+1])
            diff_int = curr - next
            diff.append(diff_int)
            dict[j] = [report, diff]

            for k in range(len(report) - 1):
                diff = report
